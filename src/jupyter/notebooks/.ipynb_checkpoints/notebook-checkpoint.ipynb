# %%
import os
import sys
import warnings
import pandas as pd
import re
from os import path

from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

pd.set_option("display.max_rows", 2000)

sys.path.append("/src") # add spending tracker dir to path

from common.constants import *

from transaction_data_tools.plugins import chase_plugin
from transaction_data_tools.plugins import amazon_plugin
from transaction_data_tools.plugins import fidelity_rewards_plugin
from transaction_data_tools.plugins import fidelity_cash_plugin
from transaction_data_tools.plugins import mint_plugin

from transaction_data_tools.data_update import get_downloads
from transaction_data_tools.data_setup_utils import update_raw_transactions_file
from transaction_data_tools.data_loader import load_raw_trans

from app.utils import to_snake
# Out:
# <style>.container { width:80% !important; }</style>

# %%
downloads = get_downloads()

# %% [markdown]
# # Amazon

# %%
amazon_filenames = amazon_plugin.get_filenames(downloads)
amazon_filenames
# Out:
# ['01-Jan-2020_to_26-Jul-2021.csv']

# %%
pd.read_csv(PATH_TO_DOWNLOADS + amazon_filenames[0], index_col = False).head()
# Out:
#   Order Date             Order ID  \
# 0   02/24/20  111-3994458-4832233
# 1   02/24/20  111-3994458-4832233
# 2   02/24/20  111-1118315-8354638
# 3   02/27/20  112-9015767-6885864
# 4   03/05/20  111-4098553-5147442
#
#                                                Title  \
# 0  SYLVANIA 7506ST.BP2 7506 SilverStar High Perfo...
# 1  Jazz Saxophone Etudes For Alto & Tenor: Book &...
# 2  Filtrete 16x25x1, AC Furnace Air Filter, MPR 1...
# 3  ColorGround Long Straight Brown 80S Mullet Dis...
# 4  Vandoren SR2625R Alto Sax JAVA Red Reeds Stren...
#
#                            Category   ASIN/ISBN  UNSPSC Code     Website  \
# 0                VEHICLE_LIGHT_BULB  B00499YC4I   25172900.0  Amazon.com
# 1                         ABIS_BOOK  0976615304   55101500.0  Amazon.com
# 2                   HVAC_AIR_FILTER  B00TUDHFJC   40161505.0  Amazon.com
# 3                               WIG  B07KYMF2DG   53131602.0  Amazon.com
# 4  INSTRUMENT_PARTS_AND_ACCESSORIES  B0027LWUBM   60131500.0  Amazon.com
#
#           Release Date Condition        Seller  ...  \
# 0                  NaN       new        iServe  ...
# 1  2005-03-01T00:00:01       new    Amazon.com  ...
# 2                  NaN       new    Amazon.com  ...
# 3                  NaN       new   ColorGround  ...
# 4                  NaN       new  Harmon Music  ...
#
#   Carrier Name & Tracking Number Item Subtotal Item Subtotal Tax  Item Total  \
# 0       AMZN_US(TBA956311714000)         $9.99             $0.60      $10.59
# 1       AMZN_US(TBA956424651000)        $24.95             $1.50      $26.45
# 2       AMZN_US(TBA957961209000)        $41.88             $2.51      $44.39
# 3       AMZN_US(TBA982600724000)        $18.90             $1.13      $20.03
# 4   USPS(9400111899223340711308)        $30.95             $1.86      $32.81
#
#   Tax Exemption Applied  Tax Exemption Type  Exemption Opt-Out Buyer Name  \
# 0                   NaN                 NaN                NaN      Caleb
# 1                   NaN                 NaN                NaN      Caleb
# 2                   NaN                 NaN                NaN      Caleb
# 3                   NaN                 NaN                NaN      Caleb
# 4                   NaN                 NaN                NaN      Caleb
#
#   Currency Group Name
# 0      USD        NaN
# 1      USD        NaN
# 2      USD        NaN
# 3      USD        NaN
# 4      USD        NaN
#
# [5 rows x 36 columns]

# %%
logs = amazon_plugin.update(downloads)
print(logs)
# Out:
# UPDATING AMAZON RECORDS
#
# updating: /src/transaction_data/raw/amazon/transactions.csv
#
# using: /src/transaction_data/downloads/01-Jan-2020_to_26-Jul-2021.csv
#
# New transactions: 0. Total: 222
#
# --------------------

# %%
amazon_df = amazon_plugin.load_trans()
amazon_df.head()
# Out:
#          date transaction_type  amount account_name  \
# 0  2020-02-24            debit   10.59       AMAZON
# 1  2020-02-24            debit   26.45       AMAZON
# 2  2020-02-24            debit   44.39       AMAZON
# 3  2020-02-27            debit   20.03       AMAZON
# 4  2020-03-05            debit   32.81       AMAZON
#
#                                 original_description
# 0  SYLVANIA 7506ST.BP2 7506 SilverStar High Perfo...
# 1  Jazz Saxophone Etudes For Alto & Tenor: Book &...
# 2  Filtrete 16x25x1, AC Furnace Air Filter, MPR 1...
# 3  ColorGround Long Straight Brown 80S Mullet Dis...
# 4  Vandoren SR2625R Alto Sax JAVA Red Reeds Stren...

# %% [markdown]
# # Chase

# %% [markdown]
# # Fidelity Cash

# %%
def load_trans() -> pd.DataFrame:
    """Load fidelity rewards transactions"""
    assert path.exists(PATH_TO_FIDELITY_CASH)

    df = pd.read_csv(PATH_TO_FIDELITY_CASH)
    df.columns = [to_snake(col) for col in df.columns]
    
    #df["original_description"] = df["name"]
    #df["date"] = df["date"].apply(lambda x: pd.to_datetime(x).date())
    #df["transaction_type"] = df["transaction"].apply(lambda x: x.lower())
    #df["amount"] = df["amount"].apply(abs)
    #df["account_name"] = "Fidelity Rewards"

    return df #[RAW_TRANSACT_SCHEMA]

# %%
def get_filenames(downloads) -> str:
    """identify all fidelity_credit_card transactions"""

    regex = r"History_for_Account_Z07707961.*\.csv"

    files = []
    for d in downloads:
        match = re.match(regex, d)
        if match:
            files.append(match.group())

    return files

# %%
get_filenames(downloads)
# Out:
# ['History_for_Account_Z07707961.csv']

# %%
pd.read_csv(PATH_TO_DOWNLOADS + 'History_for_Account_Z07707961.csv').head()
# Out:
#                                                                                                                                                                                                                Brokerage
# Run Date    Action                                             Symbol Security Description                     Security Type Quantity Price ($) Commission ($) Fees ($) Accrued Interest ($) Amount ($)  Settlement Date
#  08/10/2021  Electronic Funds Transfer Paid (Cash)                     No Description                          Cash          NaN      NaN       NaN            NaN      NaN                  -300                    NaN
#  07/30/2021  INTEREST EARNED FDIC INSURED DEPOSIT AT JP MOR...  QIMHQ  FDIC INSURED DEPOSIT AT JP MORGAN BK NO Cash          NaN      NaN       NaN            NaN      NaN                  0.02                    NaN
#              DIRECT DEBIT Turkson ManagePayment (Cash)                 No Description                          Cash          NaN      NaN       NaN            NaN      NaN                  -1564.05                NaN
#              DIRECT DEBIT CARDMEMBER SERWEB PYMT (Cash)                No Description                          Cash          NaN      NaN       NaN            NaN      NaN                  -2713.39                NaN

# %%
def update(downloads) -> str:
    logs = "\n\nUpdating fidelity cash records".upper()
    filenames = get_filenames(downloads)
    for file in filenames:
        logs += update_raw_transactions_file(
            PATH_TO_FIDELITY_CASH, PATH_TO_DOWNLOADS + file, FIDELITY_CASH_SCHEMA
        )
    return logs

# %%
update(downloads)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1ecee4e476f6> in <module>
# ----> 1 update(downloads)
#
# <ipython-input-16-7c0cb85829c9> in update(downloads)
#       4     for file in filenames:
#       5         logs += update_raw_transactions_file(
# ----> 6             PATH_TO_FIDELITY_CASH, PATH_TO_DOWNLOADS + file, FIDELITY_CASH_SCHEMA
#       7         )
#       8     return logs
#
# NameError: name 'FIDELITY_CASH_SCHEMA' is not defined
