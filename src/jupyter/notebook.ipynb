# %%
import os
import warnings
import pandas as pd
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))

pd.set_option("display.max_rows", 2000)

import sys
sys.path.append("../") # add parent dir to path

from common.constants import *
from app.data_loader import load_catted_trans
# Out:
# <style>.container { width:80% !important; }</style>

# %%
downloads = os.listdir("/Users/caleb.crouse/downloads/")

# %%
downloads
# Out:
# ['EP attack diagram.jpg',
#  'download (1).png',
#  'md_7_msp_70_msl_25.png',
#  'eclipse-java-mars-1-macosx-cocoa-x86_64.tar.gz',
#  'Install Spotify 2.app',
#  'periodic_beaconing_http.yml',
#  'EP attack diagram.png',
#  'Runs Test for Randomness.pdf',
#  'IMG-2722.JPG',
#  'intro-to-pcap-public-release.pptx',
#  'ad.pdf',
#  'CAIM',
#  'HttpBeaconValidator (7).pdf',
#  'jitter.csv',
#  'mactex-20180417.pkg',
#  'IMG-2904.JPG',
#  '02 Feb 19 WeeklyV1.docx',
#  'HttpBeaconValidator (12).pdf',
#  'jsbach_chorals_harmony',
#  'SecureMessage (1).pdf',
#  'isaac_anthony_resume.pdf',
#  'JingyaoLiu_RADAR2009_ANewPulseDeinterleavingAlgorithmBasedonMultipleHypothesisTracking.pdf',
#  'rules_export (1).ndjson',
#  '38047873_268369597277921_3455172353498021888_n.mp4',
#  'KristofLadnyResume.pdf',
#  'dev-schedule - dev_schedule.csv',
#  'ad (1).pdf',
#  '5409A614-F757-4AC6-9711-E37161E754AD.MP4',
#  '09-015.pdf',
#  '4.-Jupiter-1 (1).mp3',
#  'Alert Creator Tech Framework (1).xml',
#  'Jupiter-Alto-Sax-1 (1).pdf',
#  'ShowBillImage (4).pdf',
#  'Elevano-SrDataScientist-ScottSwensen.pdf',
#  'Quantum 1on1 Quick Reference Guide (1).pdf',
#  'MASTER ONE-ON-ONE AGENDA DONT EDIT.docx',
#  'siddhi-gpl-execution-streamingml-2.0.0.jar',
#  '09 Jun 18 WeeklyV1.docx',
#  'paystatements.pdf',
#  'video-game-sales-xgboost.ipynb',
#  'RStudio-1.1.453.dmg',
#  'caleb_kafka_consumer (2).ipynb',
#  'lecture6 (4).ppt',
#  'ADinf.c',
#  'jre-8u171-macosx-x64.dmg',
#  'R-3.5.0.pkg',
#  'Caleb Crouse Resume Jan 2021.pdf',
#  '08 Dec 18 Weekly V1.docx',
#  'DirectLetter.pdf',
#  'rva-vm-cyberanalytics-02.ironnet.io_03413c142a9d4978a177c64d0088bfaa.parquet (1).snappy',
#  'Soundflower-2-0b2.dmg',
#  'Caleb Crouse Resume Jan 2021 (1).pdf',
#  'generated_cron_s12_fe_http_2_artifacts (2).zip',
#  'Event Entity Standardization.docx',
#  'download.png',
#  '.DS_Store',
#  'Miniconda3-4.6.14-MacOSX-x86_64.sh',
#  'Health_Savings_Account_Verification_Form_03042019.pdf',
#  'ShowBillImage (5).pdf',
#  'main.pdf',
#  'Alert Creator Tech Framework.drawio',
#  'LogitsandtigersandbearsohmyAbrieflookatthesimplemathoflogisticregressionandhowitcanimprovedisseminationofresults..pdf',
#  'Zoom (1).pkg',
#  'MASTER LEASE - PH^LLLLN701 -  Oct2020_encrypted_ (1).pdf',
#  'calebchristian.docx',
#  'results 3',
#  'Resume Fall 2018.docx',
#  'Event Dedup Example - Sheet1.csv',
#  'correlation_view.pptx',
#  '2.1.ipynb',
#  'clustering_ndss.pdf',
#  'IMG-2135.JPG',
#  'rank_version_von_neumann_test.pdf',
#  'Automatic_feature_selection_for_anomaly_detection.pdf',
#  'gof_for_geometric_distribution.pdf',
#  'HttpBeaconValidator (13).pdf',
#  'ep_SFD_beaconing_scenario.html',
#  'MASTER_LEASE_PH_LLLLN701_Oct2020.pdf',
#  'HttpBeaconValidator (6).pdf',
#  'results 2',
#  '_F4A7212b.jpg',
#  'ADinf.c.zip',
#  'theme-2075.xml',
#  '.localized',
#  'Caleb Crouse Resume Jan 2021.docx',
#  'Untitled document.pdf',
#  'Chase7973_Activity_20210809.CSV',
#  'rand1.pdf',
#  'MASTER LEASE - PH^LLLLN701 -  Oct2020.pdf',
#  'IMG-2861.JPG',
#  'eclipse-inst-jre-mac64.dmg',
#  'Caleb.p12',
#  'IMG-1722 (1).JPG',
#  'jdk-10.0.1_osx-x64_bin.dmg',
#  '16594-75959-1-PB.pdf',
#  'reuters21578.tar.gz',
#  'Caleb (1).txt',
#  'MASTER LEASE - PH^LLLLN701 -  Oct2020_encrypted_.pdf',
#  'Runs Test for Randomness (1).pdf',
#  'HUNT-428 Info.xlsx',
#  'Analytic Entity Descriptions.xlsx',
#  'Uniform-IEEE-1987.pdf',
#  'lecture6.ppt',
#  'kolmo (1).pdf',
#  'ShowBillImage (2).pdf',
#  'rules_export (2).ndjson',
#  'ComparisonsoftheGoodnessofFitTestsfortheGeometricDistribution.pdf',
#  'ideaIC-2020.1.1.dmg',
#  'Proposed 3.jpg',
#  'jitter (1).csv',
#  'Dome Analytics_Enrichments-Page-2.png',
#  'Resume2021S.pdf',
#  'theme-30564.xml',
#  'HttpBeaconValidator (18).pdf',
#  'Jupiter-Alto-Sax-1.pdf',
#  '_F4A7210.jpg',
#  'jspi.pdf',
#  '47-55-1-PB.pdf',
#  'md_8.png',
#  'Logistic+Regression+with+a+Neural+Network+mindset+v5.ipynb',
#  'lecture6 (3).ppt',
#  'Lecture13_NonParametricStatistics.ppt',
#  '1-s2.0-S111001681630059X-main.pdf',
#  '_F4A6130.png',
#  'SFD_beaconing_scenario.zip',
#  '794d02174df00a76b50953626f7b934f69e1.pdf',
#  'datascience.pem',
#  'collecting_rsi_info.ipynb',
#  'PolarPlunge_AfterGroup_1.png',
#  'VSCode-darwin-stable.zip',
#  'beaconer.linux.amd64',
#  'Aaron Graham  and 378 others.vcf',
#  'HttpBeaconValidator (1).pdf',
#  'Caleb Crouse Resume Jan 2021 (1) (3).pdf',
#  'SFD_beaconing_scenario',
#  'Polygraph- Automatically Generating Signatures for Polymorphic Worms.pdf',
#  'HttpBeaconValidator (14).pdf',
#  'Caleb Crouse Ironnet.p12',
#  'Comparing anomaly detection techniques for HTTP.pdf',
#  'Wireshark 3.0.2 Intel 64.dmg',
#  '-.txt',
#  'au_lab.zip',
#  'HttpBeaconValidator (15).pdf',
#  '210123NHamlettDataScienceFed.pdf',
#  'ideaIC-2021.1.2.dmg',
#  'Caleb Crouse Resume Jan 2021 (1) (2).pdf',
#  'ep_cobalt.tgz',
#  '08.19 IronNet Cybersecurity Mutual of Omaha Benefit Summaries.pdf',
#  'xaa',
#  'ideaIC-2020.3.4.dmg',
#  'SpotifyInstaller.zip',
#  'AnApproachforMalwareBehaviorIdentificationandClassification.pdf',
#  'SecureMessage.pdf',
#  'EN_EnrollmentsSummary_2019_12_13_124335.pdf',
#  'diagram_2.JPG',
#  'selected_data_1.json',
#  'mean_sev_over_strata.png',
#  'lecture6 (2).ppt',
#  'ideaIC-2021.1.1.dmg',
#  '98292.jpg',
#  'rules_export (3).ndjson',
#  '10795-29868-3-PB.pdf',
#  'Anomaly-based intrusion detection in software as a service.pdf',
#  'discrete_uniform_tests_gof.pdf',
#  'Chase7973_Activity_20200714.CSV',
#  'Mars-Alto-Sax-1.pdf',
#  'codebeautify (2).c',
#  'eventLogs-spark-application-1616702748477-with-checkpoint.zip',
#  'ShowBillImage (3).pdf',
#  'A_comprehensive_survey_on_network_anomaly_detection_LINK.pdf',
#  'TrendData6-01--7-13.csv',
#  'visualizing label decisions.zip',
#  '008af3aed2193cae5f4fa8a467f4f27c8057.pdf',
#  'data_analytics_2018_5_30_60121.pdf',
#  'diagram_1.JPG',
#  'SKM_C45818101615100.pdf',
#  'Resume_MichaelLowney_GetHired (1).pdf',
#  'Miniconda3-latest-MacOSX-x86_64hey.sh',
#  '2019_TaxReturn.pdf',
#  'SFD_beaconing_scenario.ipynb',
#  'reference.json',
#  'fe_cerebro_scenarios.htm',
#  'lecture6 (1).ppt',
#  'Alert Creator Tech Framework (2).drawio',
#  'visualizing label decisions',
#  'Install Spotify.app',
#  'md_10.png',
#  'Untitled spreadsheet.xlsx',
#  'Chase7973_Activity_20200309.CSV',
#  'EP attack diagram (1).png',
#  'kolmo.pdf',
#  'Caleb Crouse Resume Jan 2021 (1).docx',
#  '4.-Jupiter-1.mp3',
#  'out.csv',
#  'ADinf 2.c',
#  'IronNet Corporate OKRs.pdf',
#  'bny_raw_parquet.txt',
#  'nbh_SFD_beaconing_scenario.html',
#  'results',
#  'Access to Care - Cigna .pdf',
#  'covidia_1.05_updated.xlsx',
#  'Network_traffic_classifier_with_convolutional_and_.pdf',
#  '3710 N Rosser St # 204 - 3710 N Rosser St # 204 -.pdf',
#  'theme-66.epf',
#  'rules_export.ndjson',
#  'Anagram_A_Content_Anomaly_Detector_Resistant_to_Mi.pdf',
#  'VEGdVMnCe73PITdwtQLQ1543525472.pdf',
#  '25859790 (1).pdf',
#  'HttpBeaconValidator (16).pdf',
#  'AlAhmadi+and+Martinovic,+MalClassifier+-+Malware+family+classification+using+network+flow+sequence+behaviour.pdf',
#  'file_cabinet_ironnet__files',
#  'Caleb Crouse Resume Jan 2021 (1) (1).pdf',
#  'HttpBeaconValidator (3).pdf',
#  'Certs (3) (1).zip',
#  'codebeautify (1).c',
#  'Certs',
#  'KDD95-044.pdf',
#  'Product Structure.jpeg',
#  'analytic_provided_context_values_analysis.html',
#  'Runs Test for Randomness (4).pdf',
#  'JASA1982RankvonNeumann.pdf',
#  'Runs Test for Randomness (5).pdf',
#  'BotMiner_Clustering_Analysis_of_Network_Traffic_fo.pdf',
#  'md_6.png',
#  'report.txt',
#  'captures___10___generated___3.3.2___parquet___httpprotocol___year=2018___month=4___day=4___hour=18___.rva-vm-cyberanalytics-02.ironnet.io_59d33ff1541546d5a87a32f6cf141312.parquet.snappy.crc',
#  '021420 Big Band Rehearsal d2.mp3',
#  'ShowBillImage.pdf',
#  'toward_supervised_anomoly_detection.pdf',
#  '01 Jun 19 Weekly V1.docx',
#  '533111.jpg',
#  'HttpBeaconValidator (2).pdf',
#  'IMG-1722.JPG',
#  'Event Database and Schema Discussion.pdf',
#  'caleb_kafka_consumer.ipynb',
#  'HttpBeaconValidator.pdf',
#  'US9948671.pdf',
#  'HttpBeaconValidator (17).pdf',
#  'multi_event_type_alert.png',
#  'reuters21578',
#  '3710 N Rosser St # 204 - 3710 N Rosser St # 204 - (1).pdf',
#  'download_novel_traffic_relationship.html',
#  'SM_80.pdf',
#  'Alert Creator Tech Framework Parquet.drawio',
#  'caleb_kafka_consumer (1).ipynb',
#  'Caleb.txt',
#  'visualize_cc_channels.htm',
#  'md_5.png',
#  'Zoom.pkg',
#  'kolmo (2).pdf',
#  'Miniconda3-latest-MacOSX-x86_64.sh',
#  'ShowBillImage (1).pdf',
#  'codebeautify.c',
#  'jitter (2).csv',
#  'Caleb Crouse Ironnetcyber.p12',
#  'Image-classification-transfer-learning.ipynb',
#  'thinkorswim_installer.dmg',
#  'survey_of_outlier_detection_methods.pdf',
#  'file_cabinet_ironnet_.htm',
#  'lect5.ppt',
#  'md_4.png',
#  'SpotifyInstaller (1).zip',
#  'Chase7973_Activity_20200309 (1).CSV',
#  '-.rs',
#  'ideaIC-2019.3.5.dmg',
#  'E101.D_2017EDP7294.pdf',
#  'isaac_anthony_resume (1).pdf',
#  'TIPro_WT_setup_4.2.0.exe',
#  'HttpBeaconValidator (10).pdf',
#  'Untitled spreadsheet.xlsx.cpgz',
#  'IMG-2717.JPG',
#  'Untitled Diagram.drawio',
#  'LogExpfunctions.doc',
#  'untitled.png',
#  'HttpBeaconValidator (5).pdf',
#  'AutoIDCard.pdf',
#  'transactions.csv',
#  'multi_event_type_alert (1).png',
#  'IMG-2861 (1).JPG',
#  '23 Feb 19 Weekly V1.docx',
#  'Network_Traffic_Anomaly_Detection_Using_Recurrent_.pdf',
#  'RyanDorris.pdf',
#  'Runs Test for Randomness (2).pdf',
#  'generated_cron_s12_fe_http_2_artifacts.zip',
#  'R-4.0.0.pkg',
#  'Data_Alogarithms.pptx',
#  'eclipse-inst-mac64 (1).dmg',
#  'Domain First Conclusions and Results.docx',
#  'Chase7973_Activity_20190715.CSV',
#  'rva-vm-cyberanalytics-02.ironnet.io_03413c142a9d4978a177c64d0088bfaa.parquet.snappy',
#  '2019 Annual Review Process FINAL (1).pdf',
#  'generated_cron_s12_fe_http_2_artifacts (1).zip',
#  'Aflac Interest Sheet (1).docx',
#  'Dome Analytics_Enrichments.png',
#  'HttpBeaconValidator (9).pdf',
#  'EP_attack_alert_logic_analysis.html.zip',
#  'Alert Creator Tech Framework (1).drawio',
#  'audacity-macosx-ub-2.1.0.dmg',
#  'Proposed Product Structure No Groups.jpeg',
#  'Alert Creator Tech Framework Postgres.drawio',
#  'IMG-1963.JPG',
#  'beaconSamples.tgz',
#  'ShowBillImage (6).pdf',
#  'Thank You Follow Up - Caleb Crouse.docx',
#  '1-s2.0-S0167404818305546-main.pdf',
#  'consistent_beaconing_http.yml',
#  'generated.html',
#  'Zoom (2).pkg',
#  'github-recovery-codes.txt',
#  'Malware Originated HTTP Traffic Detection Utilizing Cluster Appearance Ratio.pdf',
#  'Proposed Product Structure.jpeg',
#  'MASTER LEASE - PH^LLLLN701 -  Oct2020_encrypted_ (2).pdf',
#  'alert_filters.png',
#  '25859790.pdf',
#  'xab',
#  'python-3.6.8-macosx10.9.pkg',
#  'minimal-landscape-wallpaper.jpg',
#  'Zoom (3).pkg',
#  'correlation_view.pptx.cpgz',
#  'jsbach_chorals_harmony.zip',
#  'CAIM.zip',
#  'ideaIU-2020.1.1.dmg',
#  'HttpBeaconValidator (8).pdf',
#  '1.-Mars-1.mp3',
#  'IMG-2710.JPG',
#  '16 June 2018 Weekly V1.docx',
#  'index.doc',
#  'eclipse-inst-mac64.dmg',
#  'caleb_crouse.crt',
#  '9783790821208-c1.pdf',
#  'Garc-a_et_al-2014-Security_and_Communication_Networks.pdf',
#  'workshopbook2018.pdf',
#  'Runs Test for Randomness (3).pdf',
#  'lect5 (1).ppt',
#  'flink-1.11.2-bin-scala_2.12.tgz',
#  'lowCoiComms.csv',
#  '81a0db06-97b5-42ae-b79d-980c7a9cc91f.csv',
#  'payStatement.pdf',
#  'fe_cerebro_scenarios_files',
#  'xac',
#  'image.png',
#  '26 Jan 19 WeeklyV!.docx',
#  '01-Jan-2020_to_26-Jul-2021.csv',
#  '2 Jun 18 Weekly V1.docx',
#  'HttpBeaconValidator (4).pdf',
#  'Completed - ADP Employee Direct Deposit Enrollment Form with Percentages.pdf',
#  'Anaconda3-2019.03-MacOSX-x86_64.pkg',
#  'IMG-2713.JPG',
#  'chi-sq_explanation.doc',
#  'MADE-cybersecurity-model.pdf',
#  'Aaron Graham .vcf',
#  'HttpBeaconValidator (11).pdf',
#  'Untitled presentation.png',
#  'Alert Creator Tech Framework.xml',
#  'SecureMessage (2).pdf']

# %%
df = pd.read_csv("~/downloads/Chase7973_Activity_20210809.CSV", index_col=False)

# %%
df.head()
# Out:
#   Details Posting Date                                        Description  \
# 0   DEBIT   08/04/2021  INSUFFICIENT FUNDS FEE FOR A $96.62 RECURRING ...
# 1   DEBIT   08/04/2021  ATHLETICGREENS WWW.ATHLETICG NV              0...
# 2   DEBIT   08/04/2021  APPLE.COM/BILL 408-974-1010 CA               0...
# 3   DEBIT   08/02/2021  USAA P&C EXT     AUTOPAY    189602714       WE...
# 4   DEBIT   08/02/2021  Coinbase.com     LSDCFVQM   LSDCFVQM00b4    WE...
#
#    Amount             Type  Balance  Check or Slip #
# 0  -34.00  FEE_TRANSACTION   -87.95              NaN
# 1  -96.62       DEBIT_CARD   -53.95              NaN
# 2  -15.99       DEBIT_CARD    42.67              NaN
# 3  -49.74        ACH_DEBIT    58.66              NaN
# 4 -300.00        ACH_DEBIT   108.40              NaN

# %%
import re
from datetime import datetime

CHASE_SCHEMA = [
    "Details",
    "Posting",
    "Date",
    "Description",
    "Amount",
    "Type",
    "Balance",
    "Check or Slip #"
]



def get_chase_filenames(downloads):
    """identify chase transactions"""
    chase_regex = r"Chase7973_Activity_\d+.CSV"

    chase_downloads = []
    for d in downloads:
        match = re.match(chase_regex, d)
        if match:
            chase_downloads.append(match.group())

    dates = []
    for c in chase_downloads:
        date_string = c.replace(".CSV", "").split("_")[-1]
        dates.append(datetime.strptime(date_string, '%Y%m%d'))

    max_date = max(dates)
    max_index = dates.index(max_date)

    return chase_downloads[max_index]

# %%
get_chase_filenames(downloads)
# Out:
# 'Chase7973_Activity_20210809.CSV'

# %%
pd.read_csv(get_chase_filenames(downloads))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-90aec83a4e35> in <module>
# ----> 1 pd.read_csv(get_chase_filenames(downloads))
#
# ~/virtual_envs/ds3/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/virtual_envs/ds3/lib/python3.9/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/virtual_envs/ds3/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/virtual_envs/ds3/lib/python3.9/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/virtual_envs/ds3/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/virtual_envs/ds3/lib/python3.9/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/virtual_envs/ds3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Chase7973_Activity_20210809.CSV'

# %%
# remove amzn and auth transactions
# basically transactions we just want to ignore completely
def is_false_transaction(descr) -> bool:
    substrings = ["amzn", "amazon", "auth :"]
    for s in substrings:
        if s in descr.lower():
            return True
    return False

# %%
df = pd.read_csv("../data/categorized/transactions.csv")

# %%
def replace_sports(txt):
    if txt == "sports":
        return "sporting"
    return txt

# %%
df["subcategory"] = df["subcategory"].apply(replace_sports)

# %%
df.sort_values("original_description")
# Out:
#     Unnamed: 0        date transaction_type   amount  \
# 37        46.0  2021-07-10            debit    69.46
# 35        42.0  2021-07-10            debit    46.01
# 71         NaN  2021-07-02            debit    24.99
# 46        59.0  2021-07-06            debit    15.99
# 58        78.0  2021-07-02            debit     8.02
# 10        17.0  2021-07-21            debit     8.00
# 49        62.0  2021-07-06            debit    96.62
# 63         NaN  2021-07-24            debit    13.19
# 54        73.0  2021-07-03            debit    40.94
# 42        55.0  2021-07-08            debit    18.70
# 31        38.0  2021-07-12            debit    16.50
# 69         NaN  2021-07-02            debit     9.95
# 70         NaN  2021-07-02            debit   500.00
# 72         NaN  2021-07-02            debit   500.00
# 73         NaN  2021-07-02            debit   100.00
# 0          5.0  2021-07-22            debit     2.00
# 1          6.0  2021-07-22            debit   160.00
# 36        45.0  2021-07-10            debit    15.41
# 6         13.0  2021-07-21            debit    84.79
# 65         NaN  2021-07-21            debit    84.79
# 17        24.0  2021-07-18            debit    44.44
# 25        32.0  2021-07-14           credit  3092.62
# 9         16.0  2021-07-21            debit    43.86
# 33        40.0  2021-07-11            debit     2.42
# 11        18.0  2021-07-21            debit    13.77
# 64         NaN  2021-07-21            debit    13.77
# 39        51.0  2021-07-09            debit    47.51
# 16        23.0  2021-07-19            debit    28.02
# 68         NaN  2021-07-19            debit    28.02
# 24        31.0  2021-07-15            debit    24.91
# 13        20.0  2021-07-20            debit    63.69
# 60        82.0  2021-07-02            debit     2.11
# 18        25.0  2021-07-18            debit    32.74
# 45        58.0  2021-07-06            debit    24.99
# 5         10.0  2021-07-22            debit    12.35
# 47        60.0  2021-07-06            debit    14.33
# 55        74.0  2021-07-03            debit    56.62
# 41        54.0  2021-07-08            debit    94.88
# 51        65.0  2021-07-04            debit    65.35
# 77         NaN  2021-07-01            debit    75.73
# 32        39.0  2021-07-12            debit    61.97
# 8         15.0  2021-07-21            debit    32.55
# 30        37.0  2021-07-13            debit    32.97
# 34        41.0  2021-07-11            debit     9.49
# 20        27.0  2021-07-17            debit    35.70
# 4          9.0  2021-07-22            debit   145.99
# 3          8.0  2021-07-22            debit    15.00
# 74         NaN  2021-07-01            debit    15.00
# 21        28.0  2021-07-17            debit    10.43
# 12        19.0  2021-07-20            debit     2.81
# 15        22.0  2021-07-20            debit    10.59
# 66         NaN  2021-07-20            debit    10.59
# 44        57.0  2021-07-06            debit     2.43
# 27        34.0  2021-07-13            debit   477.06
# 28        35.0  2021-07-13            debit    10.00
# 29        36.0  2021-07-13            debit     2.25
# 75         NaN  2021-07-01            debit     5.24
# 52        66.0  2021-07-04            debit     5.30
# 22        29.0  2021-07-17            debit    48.25
# 61        83.0  2021-07-02            debit    60.00
# 19        26.0  2021-07-18            debit     5.95
# 40        53.0  2021-07-09            debit     5.95
# 56        75.0  2021-07-03            debit     5.95
# 7         14.0  2021-07-21            debit    20.00
# 2          7.0  2021-07-22            debit    74.09
# 53        70.0  2021-07-03            debit     5.29
# 38        48.0  2021-07-09            debit    27.54
# 43        56.0  2021-07-07            debit    19.00
# 62        84.0  2021-07-02            debit    19.81
# 50        64.0  2021-07-05            debit     6.78
# 23        30.0  2021-07-17            debit    42.90
# 59        80.0  2021-07-02            debit  1564.05
# 14        21.0  2021-07-20            debit     9.53
# 67         NaN  2021-07-20            debit     9.53
# 48        61.0  2021-07-06            debit    23.10
# 76         NaN  2021-07-01            debit    45.85
# 26        33.0  2021-07-14            debit    38.14
# 57        77.0  2021-07-02            debit    52.45
#
#                        account_name  \
# 37  Fidelity Rewards Visa Signature
# 35  Fidelity Rewards Visa Signature
# 71                    CHASE COLLEGE
# 46                    CHASE COLLEGE
# 58  Fidelity Rewards Visa Signature
# 10  Fidelity Rewards Visa Signature
# 49                    CHASE COLLEGE
# 63                           AMAZON
# 54  Fidelity Rewards Visa Signature
# 42                    CHASE COLLEGE
# 31                    CHASE COLLEGE
# 69                    CHASE COLLEGE
# 70                    CHASE COLLEGE
# 72                    CHASE COLLEGE
# 73                    CHASE COLLEGE
# 0   Fidelity Rewards Visa Signature
# 1   Fidelity Rewards Visa Signature
# 36  Fidelity Rewards Visa Signature
# 6                            AMAZON
# 65                           AMAZON
# 17  Fidelity Rewards Visa Signature
# 25                       INDIVIDUAL
# 9   Fidelity Rewards Visa Signature
# 33  Fidelity Rewards Visa Signature
# 11                           AMAZON
# 64                           AMAZON
# 39  Fidelity Rewards Visa Signature
# 16                           AMAZON
# 68                           AMAZON
# 24  Fidelity Rewards Visa Signature
# 13  Fidelity Rewards Visa Signature
# 60  Fidelity Rewards Visa Signature
# 18  Fidelity Rewards Visa Signature
# 45                    CHASE COLLEGE
# 5   Fidelity Rewards Visa Signature
# 47  Fidelity Rewards Visa Signature
# 55  Fidelity Rewards Visa Signature
# 41  Fidelity Rewards Visa Signature
# 51  Fidelity Rewards Visa Signature
# 77  Fidelity Rewards Visa Signature
# 32  Fidelity Rewards Visa Signature
# 8   Fidelity Rewards Visa Signature
# 30  Fidelity Rewards Visa Signature
# 34  Fidelity Rewards Visa Signature
# 20  Fidelity Rewards Visa Signature
# 4   Fidelity Rewards Visa Signature
# 3   Fidelity Rewards Visa Signature
# 74                    CHASE COLLEGE
# 21  Fidelity Rewards Visa Signature
# 12  Fidelity Rewards Visa Signature
# 15                           AMAZON
# 66                           AMAZON
# 44                    CHASE COLLEGE
# 27                    CHASE COLLEGE
# 28                    CHASE COLLEGE
# 29                    CHASE COLLEGE
# 75                    CHASE COLLEGE
# 52  Fidelity Rewards Visa Signature
# 22  Fidelity Rewards Visa Signature
# 61  Fidelity Rewards Visa Signature
# 19  Fidelity Rewards Visa Signature
# 40  Fidelity Rewards Visa Signature
# 56  Fidelity Rewards Visa Signature
# 7   Fidelity Rewards Visa Signature
# 2   Fidelity Rewards Visa Signature
# 53  Fidelity Rewards Visa Signature
# 38  Fidelity Rewards Visa Signature
# 43  Fidelity Rewards Visa Signature
# 62  Fidelity Rewards Visa Signature
# 50  Fidelity Rewards Visa Signature
# 23  Fidelity Rewards Visa Signature
# 59                    CHASE COLLEGE
# 14                           AMAZON
# 67                           AMAZON
# 48                    CHASE COLLEGE
# 76                    CHASE COLLEGE
# 26  Fidelity Rewards Visa Signature
# 57                    CHASE COLLEGE
#
#                                  original_description  \
# 37                        7-ELEVEN 34038 WARRENTON VA
# 35                              AIRLIE 540-3471300 VA
# 71                   AMZ*antarestech orders@fastsp CA
# 46                     APPLE.COM/BILL 866-712-7753 CA
# 58                ARLINGTON METER PARKIN ARLINGTON VA
# 10                ASG LOT 208 WILSON BLV ARLINGTON VA
# 49                    ATHLETICGREENS WWW.ATHLETICG NV
# 63  Amazon Basics Silicone, Non-Stick, Food Safe B...
# 54                  BP#7719198MARSHALL BP MARSHALL VA
# 42                   BUND UP PE* BUND UP HTTPSWWW.BUN
# 31                   BUND UP PE* BUND UP HTTPSWWW.BUN
# 69                    CHICK-FIL-A #02931 FALLS CHURCH
# 70                       COINBASE.COM 8889087930 MWTF
# 72                       COINBASE.COM 8889087930 UV3H
# 73                       COINBASE.COM 8889087930 Z6F6
# 0                 COLONIAL PARKING #882 WASHINGTON DC
# 1                 CORE PHYSICAL THERAPY WASHINGTON DC
# 36                   CVS/PHARMACY #01381 WARRENTON VA
# 6   Clostnature Lightweight Backpacking Tent - 3 S...
# 65  Clostnature Lightweight Backpacking Tent - 3 S...
# 17              DICK'S SPORTING #290 BAILEYS CROSS VA
# 25       DIRECT DEPOSIT IRONNET CYBEDIRECT DEP (Cash)
# 9                        DISTRICT PHARMACY FAIRFAX VA
# 33                  DUNKIN #347884 Q35 GAINESVILLE VA
# 11  Dr. Sheffield’s Certified Natural Toothpaste (...
# 64  Dr. Sheffield’s Certified Natural Toothpaste (...
# 39                 EXXONMOBIL 47886833 CENTREVILLE VA
# 16  Fujifilm Instax Mini Instant Film Twin Pack (W...
# 68  Fujifilm Instax Mini Instant Film Twin Pack (W...
# 24                            GIANT 0748 ARLINGTON VA
# 13                            GIANT 0748 ARLINGTON VA
# 60                            GIANT 0748 ARLINGTON VA
# 18                            GIANT 0748 ARLINGTON VA
# 45                   GOLDS GYM VA SOUTH AR 703-683-46
# 5              GOOD FORTUNE SUPERMARK FALLS CHURCH VA
# 47                   HARRIS TEETER #0083 ARLINGTON VA
# 55                   HARRIS TEETER #0083 ARLINGTON VA
# 41                   HARRIS TEETER #0083 ARLINGTON VA
# 51                   HARRIS TEETER #0083 ARLINGTON VA
# 77                   HARRIS TEETER #0083 ARLINGTON VA
# 32                   HARRIS TEETER #0083 ARLINGTON VA
# 8                    HARRIS TEETER #0083 ARLINGTON VA
# 30                   HARRIS TEETER #0262 ARLINGTON VA
# 34                   JERSEY MIKES 6045 GAINESVILLE VA
# 20               JOJO RESTAURANT AND BA WASHINGTON DC
# 4               KINGS DOMINION ONLINE 804-876-5000 VA
# 3                LAZ PARKING 570127-FLA WASHINGTON DC
# 74                   LAZ PARKING 570127-FLAS WASHINGT
# 21                MCDONALD'S M5037 OF VA ARLINGTON VA
# 12                ORIGIN COFFEE LAB & KI ARLINGTON VA
# 15  Oven Mitts 1 Pair of Quilted Terry Cloth Linin...
# 66  Oven Mitts 1 Pair of Quilted Terry Cloth Linin...
# 44                         PARKMOBILE 770-818-9036 VA
# 27                                   POS DEBIT AIRLIE
# 28                                   POS DEBIT PAYPAL
# 29                                   POS DEBIT VATOLL
# 75                   REI #34 BAILEYS CROSS FALLS CHUR
# 52                 SHEETZ 0144 00001446 MOOREFIELD WV
# 22                         SPIDER KELLYS ARLINGTON VA
# 61                SQ *BEARDED GOAT BARBE Arlington VA
# 19                SQ *BREAD & WATER COMP Arlington VA
# 40                SQ *BREAD & WATER COMP Arlington VA
# 56                SQ *BREAD & WATER COMP Arlington VA
# 7                              SQ *SKINDC gosq.com DC
# 2                           SUR LA TABLE ARLINGTON VA
# 53                       T.J. MAXX #1459 ARLINGTON VA
# 38                       T.J. MAXX #1459 ARLINGTON VA
# 43                TST* BRONSON BIER HALL ARLINGTON VA
# 62                 TST* NORTHSIDE SOCIAL ARLINGTON VA
# 50                 TST* NORTHSIDE SOCIAL ARLINGTON VA
# 23                TST* THE RENEGADE - VA ARLINGTON VA
# 59                      Turkson Manageme Payment 4016
# 14  U.S. Kitchen Supply 13" Stainless Steel Fine M...
# 67  U.S. Kitchen Supply 13" Stainless Steel Fine M...
# 48                        UBR POSTMATES 8005928996 CA
# 76                          USAA P&C EXT AUTOPAY 1896
# 26                    WHOLEFDS CYC#10531 ARLINGTON VA
# 57                   WWW.ADVANCEAUTOPARTS 877-238-262
#
#                                           description  \
# 37                                           7-Eleven
# 35                              AIRLIE 540-3471300 VA
# 71                   AMZ*antarestech orders@fastsp CA
# 46                                     Apple.Com/Bill
# 58                                            Parking
# 10                ASG LOT 208 WILSON BLV ARLINGTON VA
# 49                                     Athleticgreens
# 63                                             Amazon
# 54                                                 Bp
# 42                                            Bund Up
# 31                                            Bund Up
# 69                                        Chick-Fil-A
# 70                                           Coinbase
# 72                                           Coinbase
# 73                                           Coinbase
# 0                                             Parking
# 1                               Core Physical Therapy
# 36                                                Cvs
# 6   Clostnature Lightweight Backpacking Tent - 3 S...
# 65                                             Amazon
# 17                                     Dicks Sporting
# 25                                            Ironnet
# 9                        DISTRICT PHARMACY FAIRFAX VA
# 33                                             Dunkin
# 11  Dr. Sheffield’s Certified Natural Toothpaste (...
# 64                                             Amazon
# 39                                              Exxon
# 16  Fujifilm Instax Mini Instant Film Twin Pack (W...
# 68                                             Amazon
# 24                                              Giant
# 13                                              Giant
# 60                                              Giant
# 18                                              Giant
# 45                                          Golds Gym
# 5              GOOD FORTUNE SUPERMARK FALLS CHURCH VA
# 47                                      Harris Teeter
# 55                                      Harris Teeter
# 41                                      Harris Teeter
# 51                                      Harris Teeter
# 77                                      Harris Teeter
# 32                                      Harris Teeter
# 8                                       Harris Teeter
# 30                                      Harris Teeter
# 34                                       Jersey Mikes
# 20               JOJO RESTAURANT AND BA WASHINGTON DC
# 4               KINGS DOMINION ONLINE 804-876-5000 VA
# 3                                             Parking
# 74                                            Parking
# 21                MCDONALD'S M5037 OF VA ARLINGTON VA
# 12                                  Origin Coffee Lab
# 15  Oven Mitts 1 Pair of Quilted Terry Cloth Linin...
# 66                                             Amazon
# 44                                            Parking
# 27                                   POS DEBIT AIRLIE
# 28                                   POS DEBIT PAYPAL
# 29                                   POS DEBIT VATOLL
# 75                                                Rei
# 52                                             Sheetz
# 22                                      Spider Kellys
# 61                                       Bearded Goat
# 19                                      Bread & Water
# 40                                      Bread & Water
# 56                                      Bread & Water
# 7                              SQ *SKINDC gosq.com DC
# 2                           SUR LA TABLE ARLINGTON VA
# 53                                          T.J. Maxx
# 38                                          T.J. Maxx
# 43                TST* BRONSON BIER HALL ARLINGTON VA
# 62                                          Northside
# 50                                          Northside
# 23                TST* THE RENEGADE - VA ARLINGTON VA
# 59                                          Paymyrent
# 14  U.S. Kitchen Supply 13" Stainless Steel Fine M...
# 67                                             Amazon
# 48                                          Postmates
# 76                                               Usaa
# 26                                        Whole Foods
# 57                                      Advanced Auto
#
#                        category               subcategory
# 37        eating & drinking out                resturants
# 35                      lodging                     hotel
# 71  subscriptions & memberships           apps & software
# 46  subscriptions & memberships           apps & software
# 58               transportation                   parking
# 10               transportation                   parking
# 49  subscriptions & memberships                  products
# 63                     shopping       health and wellness
# 54               transportation                       gas
# 42        eating & drinking out                resturants
# 31        eating & drinking out                resturants
# 69        eating & drinking out                resturants
# 70          savings & invesment                       NaN
# 72          savings & invesment                       NaN
# 73          savings & invesment                       NaN
# 0                transportation                   parking
# 1                       medical           phsical therapy
# 36                      medical                  pharmacy
# 6                      shopping                  sporting
# 65                     shopping                  sporting
# 17                     shopping                  sporting
# 25                       income                    salary
# 9                       medical                  pharmacy
# 33        eating & drinking out                resturants
# 11                     shopping       health and wellness
# 64                     shopping       health and wellness
# 39               transportation                       gas
# 16                     shopping                       NaN
# 68                     shopping                       NaN
# 24                grocery store                       NaN
# 13                grocery store                       NaN
# 60                grocery store                       NaN
# 18                grocery store                       NaN
# 45  subscriptions & memberships                       gym
# 5                 grocery store                       NaN
# 47                grocery store                       NaN
# 55                grocery store                       NaN
# 41                grocery store                       NaN
# 51                grocery store                       NaN
# 77                grocery store                       NaN
# 32                grocery store                       NaN
# 8                 grocery store                       NaN
# 30                grocery store                       NaN
# 34        eating & drinking out                resturants
# 20        eating & drinking out                      bars
# 4        amusement & recreation                       NaN
# 3                transportation                   parking
# 74               transportation                   parking
# 21        eating & drinking out                resturants
# 12        eating & drinking out              coffee shops
# 15                     shopping                home items
# 66                     shopping                home items
# 44               transportation                   parking
# 27                      lodging                     hotel
# 28  subscriptions & memberships                 streaming
# 29               transportation                       NaN
# 75                     shopping                  sporting
# 52        eating & drinking out                resturants
# 22        eating & drinking out                      bars
# 61                     services                   haircut
# 19        eating & drinking out              coffee shops
# 40        eating & drinking out              coffee shops
# 56        eating & drinking out              coffee shops
# 7                       medical                    doctor
# 2                      shopping                home items
# 53                     shopping                home items
# 38                     shopping                home items
# 43        eating & drinking out                      bars
# 62        eating & drinking out              coffee shops
# 50        eating & drinking out              coffee shops
# 23        eating & drinking out                      bars
# 59                      housing                      rent
# 14                     shopping                home items
# 67                     shopping                home items
# 48        eating & drinking out                  delivery
# 76                    insurance                       NaN
# 26                grocery store                       NaN
# 57               transportation  auto parts & maintenance
